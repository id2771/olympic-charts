# %% [markdown]
# on ne doit pas compter plusieurs fois les médailles dans les sports collectifs (une médaille pour le basket, on ne compte pas les médailles de toute l’équipe)
# donc faut identifier si il y a le mm type de médaille médailles pour un seul sport - une seule édition, grouper et

# %% [markdown]
# chatGPT : Cela passe par un groupby ou un drop_duplicates sur les colonnes qui définissent une médaille unique (pays + épreuve + édition + type de médaille)

# %%
import pandas as pd

df = pd.read_csv("athlete_events.csv")

# on enlève les médailles NA
medals = df[df['Medal'].notna()]

# %%
china = medals[medals['NOC'] == 'CHN']
china
# Out:
#             ID         Name Sex   Age  Height  Weight   Team  NOC  \
# 6433      3610    An Yulong   M  19.0   173.0    70.0  China  CHN
# 6435      3610    An Yulong   M  19.0   173.0    70.0  China  CHN
# 6436      3610    An Yulong   M  23.0   173.0    70.0  China  CHN
# 6437      3611  An Zhongxin   F  23.0   170.0    65.0  China  CHN
# 11690     6381       Ba Yan   F  21.0   183.0    78.0  China  CHN
# ...        ...          ...  ..   ...     ...     ...    ...  ...
# 270435  135269      Zou Kai   M  24.0   158.0    55.0  China  CHN
# 270436  135269      Zou Kai   M  24.0   158.0    55.0  China  CHN
# 270438  135270  Zou Shiming   M  23.0   165.0    49.0  China  CHN
# 270439  135270  Zou Shiming   M  27.0   165.0    49.0  China  CHN
# 270440  135270  Zou Shiming   M  31.0   165.0    49.0  China  CHN
#
#               Games  Year  Season            City                      Sport  \
# 6433    1998 Winter  1998  Winter          Nagano  Short Track Speed Skating
# 6435    1998 Winter  1998  Winter          Nagano  Short Track Speed Skating
# 6436    2002 Winter  2002  Winter  Salt Lake City  Short Track Speed Skating
# 6437    1996 Summer  1996  Summer         Atlanta                   Softball
# 11690   1984 Summer  1984  Summer     Los Angeles                 Basketball
# ...             ...   ...     ...             ...                        ...
# 270435  2012 Summer  2012  Summer          London                 Gymnastics
# 270436  2012 Summer  2012  Summer          London                 Gymnastics
# 270438  2004 Summer  2004  Summer          Athina                     Boxing
# 270439  2008 Summer  2008  Summer         Beijing                     Boxing
# 270440  2012 Summer  2012  Summer          London                     Boxing
#
#                                                     Event   Medal
# 6433           Short Track Speed Skating Men's 500 metres  Silver
# 6435    Short Track Speed Skating Men's 5,000 metres R...  Bronze
# 6436    Short Track Speed Skating Men's 5,000 metres R...  Bronze
# 6437                            Softball Women's Softball  Silver
# 11690                       Basketball Women's Basketball  Bronze
# ...                                                   ...     ...
# 270435                    Gymnastics Men's Floor Exercise    Gold
# 270436                    Gymnastics Men's Horizontal Bar  Bronze
# 270438                       Boxing Men's Light-Flyweight  Bronze
# 270439                       Boxing Men's Light-Flyweight    Gold
# 270440                       Boxing Men's Light-Flyweight    Gold
#
# [989 rows x 15 columns]

# %%
# goupby Team, Games, Event
problem = china.groupby(['Team', 'Games', 'Event'])
problem
