# %%
import pandas as pd
import geopandas as gpd
import matplotlib.pyplot as plt

# %%
specialisation = pd.read_csv("specialisation.csv", sep=";")

# %%
noc_regions = pd.read_csv("noc_regions.csv")

# %%
pd.set_option('display.max_rows', False)

test = specialisation.merge(noc_regions,
left_on = 'Country',
right_on = 'region',
how = 'left')

test
# Out:
#          Country  max_podium  total_podium  ratio_specialisation  NOC  \
# 0    Afghanistan           2             2              1.000000  AFG
# 1        Curacao           1             1              1.000000  AHO
# 2        Algeria           9            17              0.529412  ALG
# 3      Australia          15            29              0.517241  ANZ
# 4      Australia          15            29              0.517241  AUS
# 5      Argentina          81           274              0.295620  ARG
# 6        Armenia           8            16              0.500000  ARM
# 7      Australia         401          1320              0.303788  ANZ
# 8      Australia         401          1320              0.303788  AUS
# ..           ...         ...           ...                   ...  ...
# 183      Vietnam           2             4              0.500000  VNM
# 184     Trinidad           5             5              1.000000  TTO
# ...

# %%
specialisation
# Out:
#          Country  max_podium  total_podium  ratio_specialisation
# 0    Afghanistan           2             2              1.000000
# 1        Curacao           1             1              1.000000
# 2        Algeria           9            17              0.529412
# 3      Australia          15            29              0.517241
# 4      Argentina          81           274              0.295620
# ..           ...         ...           ...                   ...
# 144      Vietnam           2             4              0.500000
# 145     Trinidad           5             5              1.000000
# 146       Serbia          84           390              0.215385
# 147       Zambia           1             2              0.500000
# 148     Zimbabwe          15            22              0.681818
#
# [149 rows x 4 columns]

# %%
specialisation['region_corr'] = specialisation['Country'].replace(mapping)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File /usr/local/lib/python3.12/site-packages/pandas/core/indexes/base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'region'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[6], line 1
# ...

# %% [markdown]
# reste à gérer :
# * pour la liste des pays qu'on ne trouve pas dans le noc_regions.
# * Pour les pays sans médailles

# %%
url = "https://naciscdn.org/naturalearth/110m/cultural/ne_110m_admin_0_countries.zip"
world = gpd.read_file(url)

# %%
# on va merge les deux dataframes


merged = world.merge(specialisation,
left_on = 'SOVEREIGNT',
right_on = 'region',
how = 'left')

# ici je possède un dictionnaire de correspondances
# clé = region, valeur = SOVEREIGNT

{'USA': 'United States of America',
 'Trinidad': 'Trinidad and Tobago',
 'Serbia': 'Republic of Serbia',
 'Tanzania': 'United Republic of Tanzania',
 'UK': 'United Kingdom',
 'Bahamas': 'The Bahamas',
 'Macedonia': 'North Macedonia',
 'Czech Republic': 'Czechia'}

# %%
# appliquer ce mapping à ton dataframe specialisation


specialisation['SU_A3'] = specialisation['NOC'].map(mapping_noc_to_sov3)

# %% [markdown]
# reste à gérer :
# * pour la liste des pays ("SOVEREIGNT" ou "SOV_A3") qui ne correspondent à rien dans noc_regions (dans "NOC" ou "region")
# * Pour les pays sans médailles
