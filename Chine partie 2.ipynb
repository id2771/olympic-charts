# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("athlete_events.csv")
df
# Out:
#             ID                      Name Sex   Age  Height  Weight  \
# 0            1                 A Dijiang   M  24.0   180.0    80.0
# 1            2                  A Lamusi   M  23.0   170.0    60.0
# 2            3       Gunnar Nielsen Aaby   M  24.0     NaN     NaN
# 3            4      Edgar Lindenau Aabye   M  34.0     NaN     NaN
# 4            5  Christine Jacoba Aaftink   F  21.0   185.0    82.0
# ...        ...                       ...  ..   ...     ...     ...
# 271111  135569                Andrzej ya   M  29.0   179.0    89.0
# 271112  135570                  Piotr ya   M  27.0   176.0    59.0
# 271113  135570                  Piotr ya   M  27.0   176.0    59.0
# 271114  135571        Tomasz Ireneusz ya   M  30.0   185.0    96.0
# 271115  135571        Tomasz Ireneusz ya   M  34.0   185.0    96.0
#
#                   Team  NOC        Games  Year  Season            City  \
# 0                China  CHN  1992 Summer  1992  Summer       Barcelona
# ...

# %%
china = df[df['NOC'] == 'CHN']
china
# Out:
#             ID           Name Sex   Age  Height  Weight   Team  NOC  \
# 0            1      A Dijiang   M  24.0   180.0    80.0  China  CHN
# 1            2       A Lamusi   M  23.0   170.0    60.0  China  CHN
# 1072       602  Abudoureheman   M  22.0   182.0    75.0  China  CHN
# 2611      1463      Ai Linuer   M  25.0   160.0    62.0  China  CHN
# 2612      1464      Ai Yanhan   F  14.0   168.0    54.0  China  CHN
# ...        ...            ...  ..   ...     ...     ...    ...  ...
# 270443  135272     Zou Wenzhi   M   NaN     NaN     NaN  China  CHN
# 270444  135273     Zou Yuchen   M  20.0   203.0   107.0  China  CHN
# 270445  135274   Zou Zhenxian   M  28.0   184.0    72.0  China  CHN
# 270559  135318       Zu Lijun   M  26.0   188.0    87.0  China  CHN
# 270822  135445        Zuo Yue   M  21.0   192.0    88.0  China  CHN
#
#               Games  Year  Season            City       Sport  \
# 0       1992 Summer  1992  Summer       Barcelona  Basketball
# ...

# %%
china_medals = china[china['Medal'].notna()]
china_medals
# Out:
#             ID         Name Sex   Age  Height  Weight   Team  NOC  \
# 6433      3610    An Yulong   M  19.0   173.0    70.0  China  CHN
# 6435      3610    An Yulong   M  19.0   173.0    70.0  China  CHN
# 6436      3610    An Yulong   M  23.0   173.0    70.0  China  CHN
# 6437      3611  An Zhongxin   F  23.0   170.0    65.0  China  CHN
# 11690     6381       Ba Yan   F  21.0   183.0    78.0  China  CHN
# ...        ...          ...  ..   ...     ...     ...    ...  ...
# 270435  135269      Zou Kai   M  24.0   158.0    55.0  China  CHN
# 270436  135269      Zou Kai   M  24.0   158.0    55.0  China  CHN
# 270438  135270  Zou Shiming   M  23.0   165.0    49.0  China  CHN
# 270439  135270  Zou Shiming   M  27.0   165.0    49.0  China  CHN
# 270440  135270  Zou Shiming   M  31.0   165.0    49.0  China  CHN
#
#               Games  Year  Season            City                      Sport  \
# 6433    1998 Winter  1998  Winter          Nagano  Short Track Speed Skating
# ...

# %%
summer = china_medals[china_medals['Season'] == 'Summer']
summer
# Out:
#             ID          Name Sex   Age  Height  Weight   Team  NOC  \
# 6437      3611   An Zhongxin   F  23.0   170.0    65.0  China  CHN
# 11690     6381        Ba Yan   F  21.0   183.0    78.0  China  CHN
# 14077     7597  Bao Yingying   F  24.0   172.0    67.0  China  CHN
# 21260    11223    Bi Wenjing   F  14.0   142.0    35.0  China  CHN
# 33513    17282    Cai Huijue   F  16.0   174.0    63.0  China  CHN
# ...        ...           ...  ..   ...     ...     ...    ...  ...
# 270435  135269       Zou Kai   M  24.0   158.0    55.0  China  CHN
# 270436  135269       Zou Kai   M  24.0   158.0    55.0  China  CHN
# 270438  135270   Zou Shiming   M  23.0   165.0    49.0  China  CHN
# 270439  135270   Zou Shiming   M  27.0   165.0    49.0  China  CHN
# 270440  135270   Zou Shiming   M  31.0   165.0    49.0  China  CHN
#
#               Games  Year  Season         City       Sport  \
# 6437    1996 Summer  1996  Summer      Atlanta    Softball
# ...

# %%
editions = summer.groupby('Year').size()
editions
# Out:
# Year
# 1984     74
# 1988     52
# 1992     82
# 1996    106
# 2000     79
# 2004     94
# 2008    184
# 2012    125
# 2016    113
# dtype: int64

# %%
plt.figure(figsize=(12,7))
editions.plot(kind='bar')
plt.title("Nombre de médailles de la Chine aux JOs d'Été")
plt.xlabel("Année")
plt.ylabel("Nombre de médailles")
plt.show()

# %% [markdown]
# On remarque une certaine augmentation sur le long terme.
# En 2008 il y a une nette augmentation du nombre de médailles gagnées (puis une baisse aux JOs suivants) ; cela coincide avec le fait que la Chine a hebergé les JOs à Pékin cette année là.
#
# Du coup je me pose une question : est-ce que le fait de hoster les JOs offre systématiquement un coup de boost en termes de médailles ? (augmentation qui repart à la baisse par la suite)
