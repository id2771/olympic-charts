# %%
import pandas as pd

noc_regions = pd.read_csv("noc_regions.csv")

import geopandas as gpd
import matplotlib.pyplot as plt

url = "https://naciscdn.org/naturalearth/110m/cultural/ne_110m_admin_0_countries.zip"
world = gpd.read_file(url)

# %%
noc_regions
# Out:
#      NOC       region                 notes
# 0    AFG  Afghanistan                   NaN
# 1    AHO      Curacao  Netherlands Antilles
# 2    ALB      Albania                   NaN
# 3    ALG      Algeria                   NaN
# 4    AND      Andorra                   NaN
# ..   ...          ...                   ...
# 225  YEM        Yemen                   NaN
# 226  YMD        Yemen           South Yemen
# 227  YUG       Serbia            Yugoslavia
# 228  ZAM       Zambia                   NaN
# 229  ZIM     Zimbabwe                   NaN
#
# [230 rows x 3 columns]

# %%
world
# Out:
#           featurecla  scalerank  LABELRANK                   SOVEREIGNT  \
# 0    Admin-0 country          1          6                         Fiji
# 1    Admin-0 country          1          3  United Republic of Tanzania
# 2    Admin-0 country          1          7               Western Sahara
# 3    Admin-0 country          1          2                       Canada
# 4    Admin-0 country          1          2     United States of America
# ..               ...        ...        ...                          ...
# 172  Admin-0 country          1          5           Republic of Serbia
# 173  Admin-0 country          1          6                   Montenegro
# 174  Admin-0 country          1          6                       Kosovo
# 175  Admin-0 country          1          5          Trinidad and Tobago
# 176  Admin-0 country          1          3                  South Sudan
#
#     SOV_A3  ADM0_DIF  LEVEL               TYPE TLC  \
# ...

# %%
subset4 = world.loc[world['SOVEREIGNT'] == 'Curacao']
subset4


subset5 = world.loc[
    world['SOVEREIGNT']
    .str.lower()
    .str.startswith(r'cura', na=False)
]
subset5
# Out:
# Empty GeoDataFrame
# ...

# %%
subset = world.loc[world['SOV_A3'] == 'ALB', ['SOV_A3', 'ADMIN']]
subset
# Out:
#     SOV_A3    ADMIN
# 125    ALB  Albania

# %%
subset_t1 = world.loc[world['SOVEREIGNT'] == 'United States of America', ["SOV_A3","SOVEREIGNT" ]]
subset_t1
# Out:
#    SOV_A3                SOVEREIGNT
# 4     US1  United States of America
# 45    US1  United States of America

# %%
subset2 = noc_regions.loc[noc_regions['NOC'] == 'ALB', ['NOC', 'region']]
subset2
# Out:
#    NOC   region
# 2  ALB  Albania

# %%
names = ["United States of America", 
"Trinidad and Tobago", 
"Republic of Serbia", 
"United Republic of Tanzania", 
"United Kingdom", 
"The Bahamas", 
"North Macedonia", 
"Czechia"]

T3 = world['SOVEREIGNT'].isin(names)

# %%
T4 = world.loc[T3, ['SOVEREIGNT', 'SOV_A3']]
T4
# Out:
#                       SOVEREIGNT SOV_A3
# 1    United Republic of Tanzania    TZA
# 4       United States of America    US1
# 19                   The Bahamas    BHS
# 20                United Kingdom    GB1
# 45      United States of America    US1
# 143               United Kingdom    GB1
# 153                      Czechia    CZE
# 171              North Macedonia    MKD
# 172           Republic of Serbia    SRB
# 175          Trinidad and Tobago    TTO

# %%
T5 = (
    world.loc[T3, ['SOVEREIGNT', 'SOV_A3']]
    .merge(
        noc_regions[['NOC', 'region']],
        left_on='SOV_A3',
        right_on='NOC',
        how='left',
        indicator=True
    )

)
T5
# Out:
#                     SOVEREIGNT SOV_A3  NOC          region     _merge
# 0  United Republic of Tanzania    TZA  NaN             NaN  left_only
# 1     United States of America    US1  NaN             NaN  left_only
# 2                  The Bahamas    BHS  NaN             NaN  left_only
# 3               United Kingdom    GB1  NaN             NaN  left_only
# 4     United States of America    US1  NaN             NaN  left_only
# 5               United Kingdom    GB1  NaN             NaN  left_only
# 6                      Czechia    CZE  CZE  Czech Republic       both
# 7              North Macedonia    MKD  MKD       Macedonia       both
# 8           Republic of Serbia    SRB  SRB          Serbia       both
# 9          Trinidad and Tobago    TTO  TTO        Trinidad       both

# %%
names_0 = [
    "USA",
    "Trinidad",
    "Serbia",
    "Tanzania", 
    "UK",
    "Bahamas", 
    "Macedonia",
    "Czech Republic"
    ]

# %%
mask = noc_regions['region'].isin(names_0)
subset2 = noc_regions.loc[mask, ['NOC', 'region']]
subset2
# Out:
#      NOC          region
# 15   BAH         Bahamas
# 26   BOH  Czech Republic
# 54   CZE  Czech Republic
# 74   GBR              UK
# 133  MKD       Macedonia
# 175  SCG          Serbia
# 185  SRB          Serbia
# 196  TAN        Tanzania
# 197  TCH  Czech Republic
# 205  TTO        Trinidad
# 216  USA             USA
# 223  WIF        Trinidad
# 227  YUG          Serbia

# %%
df = pd.read_csv("athlete_events.csv")

# %%
codes = [
    'BHS','BHR','BRB','GB1','NL1','CZE','GRD',
    'LIE','MKD','MUS','MCO','SRB','TZA','TON'
    ,'TTO','GB1','USA','GB1',
    'US']

mask2 = world['SOV_A3'].isin(codes)
subset3 = world.loc[mask2, ['SOV_A3', 'ADMIN']]

# %%
subset3
# Out:
#     SOV_A3                        ADMIN
# 1      TZA  United Republic of Tanzania
# 19     BHS                  The Bahamas
# 20     GB1             Falkland Islands
# 130    NL1                  Netherlands
# 143    GB1               United Kingdom
# 153    CZE                      Czechia
# 171    MKD              North Macedonia
# 172    SRB           Republic of Serbia
# 175    TTO          Trinidad and Tobago

# %% [markdown]
# Je souhaite masquer les territoires sans médailles
