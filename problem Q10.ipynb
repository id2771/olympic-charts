# %%
import pandas as pd

noc_regions = pd.read_csv("noc_regions.csv")

# %%
noc_regions
# Out:
#      NOC       region                 notes
# 0    AFG  Afghanistan                   NaN
# 1    AHO      Curacao  Netherlands Antilles
# 2    ALB      Albania                   NaN
# 3    ALG      Algeria                   NaN
# 4    AND      Andorra                   NaN
# ..   ...          ...                   ...
# 225  YEM        Yemen                   NaN
# 226  YMD        Yemen           South Yemen
# 227  YUG       Serbia            Yugoslavia
# 228  ZAM       Zambia                   NaN
# 229  ZIM     Zimbabwe                   NaN
#
# [230 rows x 3 columns]

# %%
import geopandas as gpd
import matplotlib.pyplot as plt

url = "https://naciscdn.org/naturalearth/110m/cultural/ne_110m_admin_0_countries.zip"
world = gpd.read_file(url)

# %%
subset = world.loc[world['SOV_A3'] == 'ALB', ['SOV_A3', 'ADMIN']]
subset
# Out:
#     SOV_A3    ADMIN
# 125    ALB  Albania

# %%
subset2 = noc_regions.loc[noc_regions['NOC'] == 'ALB', ['NOC', 'region']]
subset2
# Out:
#    NOC   region
# 2  ALB  Albania

# %%
mask = noc_regions['NOC'].isin(['ALB','USA','FRA'])
subset2 = noc_regions.loc[mask, ['NOC', 'region']]
subset2
# Out:
#      NOC   region
# 2    ALB  Albania
# 69   FRA   France
# 216  USA      USA

# %%
df = pd.read_csv("athlete_events.csv")

# %%
df
# Out:
#             ID                      Name Sex   Age  Height  Weight  \
# 0            1                 A Dijiang   M  24.0   180.0    80.0
# 1            2                  A Lamusi   M  23.0   170.0    60.0
# 2            3       Gunnar Nielsen Aaby   M  24.0     NaN     NaN
# 3            4      Edgar Lindenau Aabye   M  34.0     NaN     NaN
# 4            5  Christine Jacoba Aaftink   F  21.0   185.0    82.0
# ...        ...                       ...  ..   ...     ...     ...
# 271111  135569                Andrzej ya   M  29.0   179.0    89.0
# 271112  135570                  Piotr ya   M  27.0   176.0    59.0
# 271113  135570                  Piotr ya   M  27.0   176.0    59.0
# 271114  135571        Tomasz Ireneusz ya   M  30.0   185.0    96.0
# 271115  135571        Tomasz Ireneusz ya   M  34.0   185.0    96.0
#
#                   Team  NOC        Games  Year  Season            City  \
# 0                China  CHN  1992 Summer  1992  Summer       Barcelona
# ...

# %%
codes = [
    'BHS','BHR','BRB','GB1','NL1','CZE','GRD',
    'LIE','MKD','MUS','MCO','SRB','TZA','TON'
    ,'TTO','GB1','USA','GB1',
    'US']

mask2 = world['SOV_A3'].isin(codes)
subset3 = world.loc[mask2, ['SOV_A3', 'ADMIN']]

# %%
subset3
# Out:
#     SOV_A3                        ADMIN
# 1      TZA  United Republic of Tanzania
# 19     BHS                  The Bahamas
# 20     GB1             Falkland Islands
# 130    NL1                  Netherlands
# 143    GB1               United Kingdom
# 153    CZE                      Czechia
# 171    MKD              North Macedonia
# 172    SRB           Republic of Serbia
# 175    TTO          Trinidad and Tobago

# %%
import matplotlib.pyplot as plt

# Sélection de l’Albanie
france = world[world['SOV_A3'] == 'FRA']

# Plot
fig, ax = plt.subplots(figsize=(6, 6))
france.plot(ax=ax, edgecolor='black', facecolor='lightgray')
ax.set_title("Albanie (SOV_A3 == 'FRA')", fontsize=14)
ax.axis('off')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[24], line 8
#       6 # Plot
#       7 fig, ax = plt.subplots(figsize=(6, 6))
# ----> 8 france.plot(ax=ax, edgecolor='black', facecolor='lightgray')
#       9 ax.set_title("Albanie (SOV_A3 == 'FRA')", fontsize=14)
#      10 ax.axis('off')
#
# File /usr/local/lib/python3.12/site-packages/geopandas/plotting.py:968, in GeoplotAccessor.__call__(self, *args, **kwargs)
#     966 kind = kwargs.pop("kind", "geo")
#     967 if kind == "geo":
# --> 968     return plot_dataframe(data, *args, **kwargs)
#     969 if kind in self._pandas_kinds:
#     970     # Access pandas plots
#     971     return PlotAccessor(data)(kind=kind, **kwargs)
#
# ...
